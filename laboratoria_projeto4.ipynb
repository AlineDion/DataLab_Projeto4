# %% [markdown]
# <a href="https://colab.research.google.com/github/AlineDion/DataLab_Python/blob/main/laboratoria_projeto4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
product_df = pd.read_csv('/content/amazon_product.csv')
review_df = pd.read_csv('/content/amazon_review.csv')

# %%
display(review_df.head())
display(product_df.head())
# Out:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# ...

# %%
print("Valores nulos em review_df:")
display(review_df.isnull().sum())

print("\nValores nulos em product_df:")
display(product_df.isnull().sum())
# Out:
# Valores nulos em review_df:
# user_id           0
# user_name         0
# review_id         0
# review_title      0
# review_content    0
# img_link          0
# product_link      0
# product_id        0
# rating            0
# rating_count      0
# z_score           0
# dtype: int64
# Valores nulos em product_df:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# about_product          0
# dtype: int64

# %%
# Imputar valores nulos em colunas numéricas pela média
for col in review_df.select_dtypes(include=['number']).columns:
    review_df[col].fillna(review_df[col].mean(), inplace=True)

for col in product_df.select_dtypes(include=['number']).columns:
    product_df[col].fillna(product_df[col].mean(), inplace=True)

# Imputar valores nulos em colunas categóricas pelo valor mais frequente (moda)
for col in review_df.select_dtypes(include=['object']).columns:
    review_df[col].fillna(review_df[col].mode()[0], inplace=True)

for col in product_df.select_dtypes(include=['object']).columns:
    product_df[col].fillna(product_df[col].mode()[0], inplace=True)

print("Valores nulos em review_df após imputação:")
display(review_df.isnull().sum())

print("\nValores nulos em product_df após imputação:")
display(product_df.isnull().sum())
# Out:
# Valores nulos em review_df após imputação:
# /tmp/ipython-input-68-3242609241.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   review_df[col].fillna(review_df[col].mean(), inplace=True)
# /tmp/ipython-input-68-3242609241.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
# prompt: Exiba o dataset após o tratamento de valores nulos.

# Exibir os datasets após o tratamento de valores nulos
print("\nDataset review_df após o tratamento de valores nulos:")
display(review_df.head())

print("\nDataset product_df após o tratamento de valores nulos:")
display(product_df.head())
# Out:
# Dataset review_df após o tratamento de valores nulos:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# ...

# %%
review_df.drop_duplicates(subset=['user_id', 'review_id', 'product_id'], inplace=True)
product_df.drop_duplicates(subset=['product_id'], inplace=True)

print("Número de linhas em review_df após remover duplicatas:", len(review_df))
print("Número de linhas em product_df após remover duplicatas:", len(product_df))
# Out:
# Número de linhas em review_df após remover duplicatas: 1360
# Número de linhas em product_df após remover duplicatas: 1351

# %%
original_review_df = pd.read_csv('/content/amazon_review.csv')
original_product_df = pd.read_csv('/content/amazon_product.csv')

removed_review_duplicates_count = len(original_review_df) - len(review_df)
removed_product_duplicates_count = len(original_product_df) - len(product_df)

print(f"Número de duplicatas removidas em review_df: {removed_review_duplicates_count}")
print(f"Número de duplicatas removidas em product_df: {removed_product_duplicates_count}")
# Out:
# Número de duplicatas removidas em review_df: 105
# Número de duplicatas removidas em product_df: 118

# %%
original_review_df = pd.read_csv('/content/amazon_review.csv')
original_product_df = pd.read_csv('/content/amazon_product.csv')

removed_review_duplicates_count = len(original_review_df) - len(review_df)
removed_product_duplicates_count = len(original_product_df) - len(product_df)

print(f"Número de duplicatas removidas em review_df: {removed_review_duplicates_count}")
print(f"Número de duplicatas removidas em product_df: {removed_product_duplicates_count}")
# Out:
# Número de duplicatas removidas em review_df: 104
# Número de duplicatas removidas em product_df: 118

# %%
# prompt: Quais valores em meu dataset estão fora do escopo do meu projeto?

print("\nInformações estatísticas de review_df:")
display(review_df.describe(include='all'))

print("\nInformações estatísticas de product_df:")
display(product_df.describe(include='all'))


review_df['rating'] = pd.to_numeric(review_df['rating'], errors='coerce')

min_rating = 1
max_rating = 5
out_of_scope_reviews = review_df[(review_df['rating'] < min_rating) | (review_df['rating'] > max_rating)]

print(f"\nAvaliações fora do escopo ({min_rating}-{max_rating}) em review_df:")
display(out_of_scope_reviews)

# Para colunas categóricas, podemos listar os valores únicos para identificar
# valores inesperados ou inconsistentes
print("\nValores únicos em colunas categóricas de review_df:")
categorical_cols_review = review_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_review:
    print(f"{col}: {review_df[col].unique()[:10]}...") # Mostrar os primeiros 10 valores únicos

print("\nValores únicos em colunas categóricas de product_df:")
categorical_cols_product = product_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_product:
    print(f"{col}: {product_df[col].unique()[:10]}...") # Mostrar os primeiros 10 valores únicos
# Out:
# Informações estatísticas de review_df:
#                                                   user_id  \
# count                                                1360
# unique                                               1193
# top     AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# freq                                                    8
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                 user_name  \
# count                                                1360
# unique                                               1193
# ...

# %%
# Converter a coluna 'rating' para numérica, tratando erros
review_df['rating'] = pd.to_numeric(review_df['rating'], errors='coerce')

# Definir o intervalo esperado para as avaliações
min_rating = 1
max_rating = 5

# Filtrar avaliações fora do escopo
review_df = review_df[(review_df['rating'] >= min_rating) & (review_df['rating'] <= max_rating)]

print(f"Número de linhas em review_df após filtrar avaliações fora do escopo: {len(review_df)}")

# Verificar se ainda há valores nulos na coluna 'rating' após a conversão e filtragem
print("\nValores nulos na coluna 'rating' após filtragem:")
display(review_df['rating'].isnull().sum())
# Out:
# Número de linhas em review_df após filtrar avaliações fora do escopo: 1360
#
# Valores nulos na coluna 'rating' após filtragem:
# np.int64(0)

# %%
print("\nValores únicos em colunas categóricas de review_df:")
categorical_cols_review = review_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_review:
    print(f"{col}: {review_df[col].unique()[:50]}...") # Mostrar os primeiros 50 valores únicos para não poluir muito a saída

print("\nValores únicos em colunas categóricas de product_df:")
categorical_cols_product = product_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_product:
    print(f"{col}: {product_df[col].unique()[:50]}...") # Mostrar os primeiros 50 valores únicos
# Out:
# Valores únicos em colunas categóricas de review_df:
# user_id: ['AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBBSNLYT3ONILA,AHCTC6ULH4XB6YHDY6PCH2R772LQ,AGYHHIERNXKA6P5T7CZLXKVPT7IQ,AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q,AENGU523SXMOS7JPDTW52PNNVWGQ,AEQJHCVTNINBS4FKTBGQRQTGTE5Q,AFC3FFC5PKFF5PMA52S3VCHOZ5FQ'
#  'AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBXNGXZJT525AQ,AHONIZU3ICIEHQIGQ6R2VFRSBXOQ,AFPHD2CRPDZMWMBL7WXRSVYWS5JA,AEZ346GX3HJ4O4XNRPHCNHXQURMQ,AEPSWFPNECKO34PUC7I56ITGXR6Q,AHWVEHR5DYLVFTO2KF3IZATFQSWQ,AH4QT33M55677I7ISQOAKEQWACYQ'
#  'AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQLWQOWZ4N3OA,AHTPQRIMGUD4BYR5YIHBH3CCGEFQ,AEUVWXYP5LT7PZLLZENEO2NODPBQ,AHC7MPW55DOO6WNCOQVA2VHOD26A,AFDI6FRPFBTNBG7BAEB7JDJSMKDQ,AFQKCEEEKXCOHTDG4WUN3XPPHJQQ,AHKUUFNMBZIDLSSPA4FEHIO2EC7Q'
# ...

# %%
print("Valores únicos em colunas categóricas de review_df:")
categorical_cols_review = review_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_review:
    print(f"\nColuna: {col}")
    print(review_df[col].unique())

print("\nValores únicos em colunas categóricas de product_df:")
categorical_cols_product = product_df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols_product:
    print(f"\nColuna: {col}")
    print(product_df[col].unique())
# Out:
# Valores únicos em colunas categóricas de review_df:
#
# Coluna: user_id
# ['AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBBSNLYT3ONILA,AHCTC6ULH4XB6YHDY6PCH2R772LQ,AGYHHIERNXKA6P5T7CZLXKVPT7IQ,AG4OGOFWXJZTQ2HKYIOCOY3KXF2Q,AENGU523SXMOS7JPDTW52PNNVWGQ,AEQJHCVTNINBS4FKTBGQRQTGTE5Q,AFC3FFC5PKFF5PMA52S3VCHOZ5FQ'
#  'AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBXNGXZJT525AQ,AHONIZU3ICIEHQIGQ6R2VFRSBXOQ,AFPHD2CRPDZMWMBL7WXRSVYWS5JA,AEZ346GX3HJ4O4XNRPHCNHXQURMQ,AEPSWFPNECKO34PUC7I56ITGXR6Q,AHWVEHR5DYLVFTO2KF3IZATFQSWQ,AH4QT33M55677I7ISQOAKEQWACYQ'
#  'AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQLWQOWZ4N3OA,AHTPQRIMGUD4BYR5YIHBH3CCGEFQ,AEUVWXYP5LT7PZLLZENEO2NODPBQ,AHC7MPW55DOO6WNCOQVA2VHOD26A,AFDI6FRPFBTNBG7BAEB7JDJSMKDQ,AFQKCEEEKXCOHTDG4WUN3XPPHJQQ,AHKUUFNMBZIDLSSPA4FEHIO2EC7Q'
#  ...
# ...

# %%
# Function to convert price strings to numeric
def convert_price_to_numeric(price_str):
    if isinstance(price_str, str):
        # Remove currency symbol and commas, then convert to float
        return float(price_str.replace('₹', '').replace(',', ''))
    return price_str # Return as is if not a string (e.g., already NaN or numeric)

# Apply the conversion function to the price columns
product_df['discounted_price'] = product_df['discounted_price'].apply(convert_price_to_numeric)
product_df['actual_price'] = product_df['actual_price'].apply(convert_price_to_numeric)

print("Data types after converting price columns:")
display(product_df.dtypes)

print("\nFirst 5 rows of product_df with numeric price columns:")
display(product_df.head())
# Out:
# Data types after converting price columns:
# product_id              object
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage     object
# about_product           object
# dtype: object
# First 5 rows of product_df with numeric price columns:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  computers&accessories|accessories&peripherals|...             399.0
# 1  computers&accessories|accessories&peripherals|...             199.0
# ...

# %%
# Padronizar a coluna 'category' em product_df
product_df['category'] = product_df['category'].str.lower().str.strip()

print("Valores únicos na coluna category após padronização:")
display(product_df['category'].unique()[:50])

print("\nPrimeiras linhas de product_df com preços convertidos:")
display(product_df.head())

print("\nPrimeiras linhas de review_df com rating_count convertido:")
display(review_df.head())
# Out:
# Valores únicos na coluna category após padronização:
# array(['computers&accessories|accessories&peripherals|cables&accessories|cables|usbcables',
#        'computers&accessories|networkingdevices|networkadapters|wirelessusbadapters',
#        'electronics|hometheater,tv&video|accessories|cables|hdmicables',
#        'electronics|hometheater,tv&video|televisions|smarttelevisions',
#        'electronics|hometheater,tv&video|accessories|remotecontrols',
#        'electronics|hometheater,tv&video|televisions|standardtelevisions',
#        'electronics|hometheater,tv&video|accessories|tvmounts,stands&turntables|tvwall&ceilingmounts',
#        'electronics|hometheater,tv&video|accessories|cables|rcacables',
#        'electronics|homeaudio|accessories|speakeraccessories|mounts',
#        'electronics|hometheater,tv&video|accessories|cables|opticalcables',
#        'electronics|hometheater,tv&video|projectors',
#        'electronics|homeaudio|accessories|adapters',
# ...

# %%
# Função para identificar outliers usando IQR
def find_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers

print("Outliers identificados em review_df (usando IQR):")
for col in review_df.select_dtypes(include=['number']).columns:
    outliers = find_outliers_iqr(review_df, col)
    print(f"\nColuna: {col} - Total de outliers: {len(outliers)}") # Explicitly print total count

    if not outliers.empty:
        # Add a row for the total count in the displayed table
        total_row = pd.DataFrame([{c: f"Total: {len(outliers)}" if c == outliers.columns[0] else '' for c in outliers.columns}])
        outliers_with_total = pd.concat([outliers.drop(columns=['z_score'], errors='ignore'), total_row], ignore_index=True)
        display(outliers_with_total)
    else:
        print(f"Coluna: {col} - Nenhum outlier encontrado.")


print("\nOutliers identificados em product_df (usando IQR):")
for col in product_df.select_dtypes(include=['number']).columns:
    outliers = find_outliers_iqr(product_df, col)
    print(f"\nColuna: {col} - Total de outliers: {len(outliers)}") # Explicitly print total count
    if not outliers.empty:
        # Add a row for the total count in the displayed table
        total_row = pd.DataFrame([{c: f"Total: {len(outliers)}" if c == outliers.columns[0] else '' for c in outliers.columns}])
        outliers_with_total = pd.concat([outliers, total_row], ignore_index=True)
        display(outliers_with_total)
    else:
        print(f"Coluna: {col} - Nenhum outlier encontrado.")
# Out:
# Outliers identificados em review_df (usando IQR):
#
# Coluna: rating - Total de outliers: 19
#                                               user_id  \
# 0   AHGHFJXREBY4F2LI3M6SFLSWC75Q,AFZWM3VVEIMWNFSTQ...
# 1   AF7EOXYL5K36BDP6PXF6K2TL5TPA,AEN7NV2P5WNHM7EXC...
# 2   AH7NTBDGAMGOFFADEVWJL3O4YQ2A,AEJUIUF6CYKRBWLSO...
# 3                        AE7CFHY23VAJT2FI4NZKKP6GS2UQ
# 4                        AGJC5O5H5BBXWUV7WRIEIOOR3TVQ
# 5   AHSYI7EUDN2RNS2IPMGAS5MKLXPQ,AHHLJNBYVOGQSFG2Q...
# 6   AFEMYJODFSKRPR4XTYKCPXMCO4YA,AH7PGDCSET6C5NOBB...
# 7   AFLLEPVLIAH2DFSHAZ77KWFM72ZA,AHY2YZWK63CNZ626M...
# 8   AFWHK4LKZHJJVZKD23JDBSMYCTWA,AG4YW4O2PIYELIEF7...
# 9   AHRDA66XO63XYCBZJMW4EUJN3BFQ,AELE2SOO7LBNHXU7U...
# 10  AHXNEJ47QV434CJ2CITRIYTIZFDQ,AHT3RLKKTOW7PESAS...
# 11  AEJKHGA26MUVUZIYWZOW4B6I4X7Q,AF3B47EOSBULYG63E...
# 12  AGHT3K4KSG5MAQUSXRDT5VNB73GA,AE4Q5XQ7SZW35EEUJ...
# 13  AH6P2FS36YMFXR6BCZY4QI3A5EGQ,AHLSHAJTU5B4XBPJG...
# 14  AELHZH2PRVKJIVTQMABOTT6LUMBQ,AGNBNAIVJCEB3TBME...
# ...

# %% [markdown]
# # Task
# Analyze the distributions of numerical columns in `review_df` and `product_df` to determine whether IQR or Z-score is a more suitable method for outlier detection for each column.

# %% [markdown]
# ## Identify numerical columns
#
# ### Subtask:
# List all columns with a numerical data type in both `review_df` and `product_df`.

# %%
numerical_cols_review = review_df.select_dtypes(include='number').columns
numerical_cols_product = product_df.select_dtypes(include='number').columns

print("Numerical columns in review_df:")
print(numerical_cols_review)

print("\nNumerical columns in product_df:")
print(numerical_cols_product)
# Out:
# Numerical columns in review_df:
# Index(['rating', 'rating_count', 'z_score'], dtype='object')
#
# Numerical columns in product_df:
# Index(['discounted_price', 'actual_price'], dtype='object')

# %% [markdown]
# ## Visualize distributions

# %% [markdown]
# **Reasoning**:
# Generate histograms and box plots for each numerical column in `review_df` and `product_df` to visualize their distributions and potential outliers.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Numerical columns in review_df: 'rating', 'rating_count', 'z_score'
numerical_cols_review = ['rating', 'rating_count', 'z_score']

# Numerical columns in product_df: 'discounted_price', 'actual_price'
numerical_cols_product = ['discounted_price', 'actual_price']

# Generate plots for review_df numerical columns
for col in numerical_cols_review:
    print(f"\nAnalyzing distribution for '{col}' in review_df:")

    # Histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(review_df[col], kde=True)
    plt.title(f'Histogram of {col} in review_df')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

    # Box plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=review_df[col])
    plt.title(f'Box Plot of {col} in review_df')
    plt.xlabel(col)
    plt.show()

# Generate plots for product_df numerical columns
for col in numerical_cols_product:
    print(f"\nAnalyzing distribution for '{col}' in product_df:")

    # Histogram
    plt.figure(figsize=(10, 6))
    sns.histplot(product_df[col], kde=True)
    plt.title(f'Histogram of {col} in product_df')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

    # Box plot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=product_df[col])
    plt.title(f'Box Plot of {col} in product_df')
    plt.xlabel(col)
    plt.show()
# Out:
# Analyzing distribution for 'rating' in review_df:
# Analyzing distribution for 'rating_count' in review_df:
# Analyzing distribution for 'z_score' in review_df:
# Analyzing distribution for 'discounted_price' in product_df:
# Analyzing distribution for 'actual_price' in product_df:

# %% [markdown]
# ## Interpret results
#
# ### Subtask:
# Based on the visualizations and statistics, discuss whether the data is approximately normally distributed or skewed, and recommend whether the IQR or Z-score method is more suitable for outlier detection for each column.

# %%
print("Analysis and Recommendation for Outlier Detection Method:")

# Analysis for review_df
print("\nReview DataFrame (review_df):")
print("------------------------------")

# Analyze 'rating'
print("\nColumn: rating")
print("Distribution Shape: The histogram and box plot show that the 'rating' distribution is somewhat left-skewed, as indicated by the negative skewness (-1.2287). The positive kurtosis (4.2419) suggests heavier tails than a normal distribution.")
print("Recommended Method: Due to the skewness and heavier tails, the IQR method is likely more robust for outlier detection in the 'rating' column compared to the Z-score method which assumes normality.")

# Analyze 'rating_count'
print("\nColumn: rating_count")
print("Distribution Shape: The histogram and box plot clearly show that the 'rating_count' distribution is highly right-skewed. This is strongly supported by the very high positive skewness (5.6569) and kurtosis (39.9162). There are many values clustered at the lower end and a long tail of larger values.")
print("Recommended Method: Given the extreme skewness and heavy tails, the IQR method is significantly more suitable for outlier detection in 'rating_count'. The Z-score method would be highly influenced by the extreme values.")

# Analyze 'z_score'
print("\nColumn: z_score")
print("Distribution Shape: The 'z_score' distribution is also highly right-skewed, as expected since it is derived from 'rating_count'. The skewness (5.6569) and kurtosis (39.9162) values are the same as 'rating_count'. The box plot also shows many outliers on the higher end.")
print("Recommended Method: Similar to 'rating_count', the IQR method is more appropriate for outlier detection in the 'z_score' column due to the strong skewness and heavy tails.")

# Analysis for product_df
print("\nProduct DataFrame (product_df):")
print("-------------------------------")

# Analyze 'discounted_price'
print("\nColumn: discounted_price")
print("Distribution Shape: The histogram and box plot indicate that the 'discounted_price' distribution is strongly right-skewed, with a high positive skewness (4.3017) and kurtosis (23.8326). Most values are concentrated at the lower end.")
print("Recommended Method: The IQR method is recommended for outlier detection in 'discounted_price' because of the significant right-skewness and heavy tails.")

# Analyze 'actual_price'
print("\nColumn: actual_price")
print("Distribution Shape: The 'actual_price' distribution is also strongly right-skewed, similar to 'discounted_price'. The high positive skewness (4.4333) and kurtosis (27.9310) confirm this. The box plot shows numerous outliers on the higher end.")
print("Recommended Method: Given the strong right-skewness and heavy tails, the IQR method is more suitable for outlier detection in the 'actual_price' column.")
# Out:
# Analysis and Recommendation for Outlier Detection Method:
#
# Review DataFrame (review_df):
# ------------------------------
#
# Column: rating
# Distribution Shape: The histogram and box plot show that the 'rating' distribution is somewhat left-skewed, as indicated by the negative skewness (-1.2287). The positive kurtosis (4.2419) suggests heavier tails than a normal distribution.
# Recommended Method: Due to the skewness and heavier tails, the IQR method is likely more robust for outlier detection in the 'rating' column compared to the Z-score method which assumes normality.
#
# Column: rating_count
# Distribution Shape: The histogram and box plot clearly show that the 'rating_count' distribution is highly right-skewed. This is strongly supported by the very high positive skewness (5.6569) and kurtosis (39.9162). There are many values clustered at the lower end and a long tail of larger values.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   Based on the observed skewness and non-normal distributions, the IQR method is generally recommended as the more suitable outlier detection method for all analyzed numerical columns (`rating`, `rating_count`, `z_score`, `discounted_price`, `actual_price`) in both dataframes.
